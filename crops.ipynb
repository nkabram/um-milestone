# %%
pest = pd.read_csv('./pesticides.csv')

# %%
print_info(pest, 'pest')
# Out:
# **pest:**
# *Data Columns:*
# Index(['Area Code', 'Area Code (M49)', 'Area', 'Item Code', 'Item',
#        'Element Code', 'Element', 'Year Code', 'Year', 'Unit', 'Value',
#        'Flag'],
#       dtype='object')
# *Dataframe info:*
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112350 entries, 0 to 112349
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Area Code        112350 non-null  int64
#  1   Area Code (M49)  112350 non-null  object
#  2   Area             112350 non-null  object
#  3   Item Code        112350 non-null  int64
#  4   Item             112350 non-null  object
#  5   Element Code     112350 non-null  int64
#  6   Element          112350 non-null  object
#  7   Year Code        112350 non-null  int64
#  8   Year             112350 non-null  int64
#  9   Unit             112350 non-null  object
#  10  Value            112350 non-null  float64
# ...

# %%
pest.head()
# Out:
#    Area Code Area Code (M49)     Area  Item Code                Item  \
# 0          3            '008  Albania       1357  Pesticides (total)
# 1          3            '008  Albania       1357  Pesticides (total)
# 2          3            '008  Albania       1357  Pesticides (total)
# 3          3            '008  Albania       1357  Pesticides (total)
# 4          3            '008  Albania       1357  Pesticides (total)
#
#    Element Code           Element  Year Code  Year Unit  Value Flag
# 0          5157  Agricultural Use       1990  1990    t  121.0    A
# 1          5157  Agricultural Use       1991  1991    t  121.0    A
# 2          5157  Agricultural Use       1992  1992    t  121.0    A
# 3          5157  Agricultural Use       1993  1993    t  121.0    A
# 4          5157  Agricultural Use       1994  1994    t  201.0    A

# %%
pest['Area'].unique()
# Out:
# array(['Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
#        'Belgium-Luxembourg', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China',
#        'China, Hong Kong SAR', 'China, Macao SAR', 'China, mainland',
#        'China, Taiwan Province of', 'Colombia', 'Comoros', 'Congo',
#        'Cook Islands', 'Costa Rica', "Côte d'Ivoire", 'Croatia', 'Cuba',
#        'Cyprus', 'Czechia', 'Czechoslovakia',
#        "Democratic People's Republic of Korea",
# ...

# %%
yield_df['Country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belgium-Luxembourg', 'Belize',
#        'Benin', 'Bermuda', 'Bhutan', 'Bolivia (Plurinational State of)',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China',
#        'China, Hong Kong SAR', 'China, Taiwan Province of',
#        'China, mainland', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czechia',
#        'Czechoslovakia', "Côte d'Ivoire",
#        "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
pest[pest['Area'] == 'Netherlands Antilles (former)']
# Out:
#        Area Code Area Code (M49)                           Area  Item Code  \
# 61445        151            '530  Netherlands Antilles (former)       1357
# 61446        151            '530  Netherlands Antilles (former)       1357
# 61447        151            '530  Netherlands Antilles (former)       1357
# 61448        151            '530  Netherlands Antilles (former)       1357
# 61449        151            '530  Netherlands Antilles (former)       1357
# ...          ...             ...                            ...        ...
# 61713        151            '530  Netherlands Antilles (former)       1355
# 61714        151            '530  Netherlands Antilles (former)       1355
# 61715        151            '530  Netherlands Antilles (former)       1355
# 61716        151            '530  Netherlands Antilles (former)       1355
# 61717        151            '530  Netherlands Antilles (former)       1355
#
# ...

# %%
pest[pest['Area'] == 'Netherlands (Kingdom of the)']
# Out:
#        Area Code Area Code (M49)                          Area  Item Code  \
# 60677        150            '528  Netherlands (Kingdom of the)       1357
# 60678        150            '528  Netherlands (Kingdom of the)       1357
# 60679        150            '528  Netherlands (Kingdom of the)       1357
# 60680        150            '528  Netherlands (Kingdom of the)       1357
# 60681        150            '528  Netherlands (Kingdom of the)       1357
# ...          ...             ...                           ...        ...
# 61440        150            '528  Netherlands (Kingdom of the)       1355
# 61441        150            '528  Netherlands (Kingdom of the)       1355
# 61442        150            '528  Netherlands (Kingdom of the)       1355
# 61443        150            '528  Netherlands (Kingdom of the)       1355
# 61444        150            '528  Netherlands (Kingdom of the)       1355
#
#                        Item  Element Code           Element  Year Code  Year  \
# ...

# %%
unique_values_pest = pest.loc[~pest['Area'].isin(yield_df['Country']), 'Area'].unique()
unique_values_pest
# Out:
# array(['Andorra', 'Anguilla', 'Aruba', 'British Virgin Islands',
#        'China, Macao SAR', 'Falkland Islands (Malvinas)', 'Greenland',
#        'Holy See', 'Kiribati', 'Mayotte', 'Nauru',
#        'Netherlands (Kingdom of the)', 'Netherlands Antilles (former)',
#        'Norfolk Island', 'North Macedonia', 'Northern Mariana Islands',
#        'Palau', 'Palestine', 'Pitcairn',
#        'Saint Helena, Ascension and Tristan da Cunha',
#        'Sint Maarten (Dutch part)', 'Tokelau', 'Türkiye',
#        'Turks and Caicos Islands', 'Tuvalu',
#        'United Kingdom of Great Britain and Northern Ireland', 'World',
#        'Africa', 'Eastern Africa', 'Middle Africa', 'Northern Africa',
#        'Southern Africa', 'Western Africa', 'Americas',
#        'Northern America', 'Central America', 'Caribbean',
#        'South America', 'Asia', 'Central Asia', 'Eastern Asia',
#        'Southern Asia', 'South-eastern Asia', 'Western Asia', 'Europe',
# ...

# %%
yield_df['Country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belgium-Luxembourg', 'Belize',
#        'Benin', 'Bermuda', 'Bhutan', 'Bolivia (Plurinational State of)',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China',
#        'China, Hong Kong SAR', 'China, Taiwan Province of',
#        'China, mainland', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czechia',
#        'Czechoslovakia', "Côte d'Ivoire",
#        "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
# Values in yield_df's 'Country' column that are not in pest's 'Area' column
unique_values_yield = yield_df.loc[~yield_df['Country'].isin(pest['Area']), 'Country'].unique()
unique_values_yield
# Out:
# array(['Afghanistan', 'American Samoa', 'Dominica', 'Guadeloupe',
#        'Guyana', 'Martinique', 'Netherlands',
#        'Occupied Palestinian Territory', 'Puerto Rico', 'Réunion',
#        'Singapore', 'South Sudan',
#        'The former Yugoslav Republic of Macedonia', 'Turkey',
#        'United Arab Emirates', 'United Kingdom', 'Uzbekistan'],
#       dtype=object)

# %%
pest['Area'].unique()
# Out:
# array(['Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
#        'Belgium-Luxembourg', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China',
#        'China, Hong Kong SAR', 'China, Macao SAR', 'China, mainland',
#        'China, Taiwan Province of', 'Colombia', 'Comoros', 'Congo',
#        'Cook Islands', 'Costa Rica', "Côte d'Ivoire", 'Croatia', 'Cuba',
#        'Cyprus', 'Czechia', 'Czechoslovakia',
#        "Democratic People's Republic of Korea",
# ...

# %%
crops = pd.read_csv('crops.csv')

# %%
'Türkiye':'Turkey' , 'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom',
# Out:
#    Area Code Area Code (M49)         Area  Item Code Item Code (CPC)  \
# 0          2            '004  Afghanistan        221          '01371
# 1          2            '004  Afghanistan        221          '01371
# 2          2            '004  Afghanistan        221          '01371
# 3          2            '004  Afghanistan        221          '01371
# 4          2            '004  Afghanistan        221          '01371
#
#                 Item  Element Code         Element  Year Code  Year Unit  \
# 0  Almonds, in shell          5312  Area harvested       1975  1975   ha
# 1  Almonds, in shell          5312  Area harvested       1976  1976   ha
# 2  Almonds, in shell          5312  Area harvested       1977  1977   ha
# 3  Almonds, in shell          5312  Area harvested       1978  1978   ha
# 4  Almonds, in shell          5312  Area harvested       1979  1979   ha
#
#     Value Flag
# 0     0.0    E
# 1  5900.0    E
# 2  6000.0    E
# 3  6000.0    E
# 4  6000.0    E

# %%
crops['Unit'].unique()
# Out:
# array(['ha', 'hg/ha', 'tonnes', 'Head', '1000 Head', '100mg/An', 'No/An',
#        '1000 No', 'hg/An', '0.1g/An', 'No', 'hg'], dtype=object)

# %%
crops['Unit'].value_counts()
# Out:
# Unit
# tonnes       1437541
# ha            793556
# hg/ha         761663
# Head          349993
# hg/An         172264
# 1000 Head     128286
# 0.1g/An        47900
# 100mg/An       29250
# No             16523
# 1000 No         9374
# No/An           8550
# hg              6268
# Name: count, dtype: int64

# %%
crops['Element Code'].unique()
# Out:
# array([5312, 5419, 5510, 5111, 5320, 5112, 5410, 5413, 5513, 5313, 5417,
#        5424, 5321, 5420, 5318, 5114, 5314, 5422], dtype=int64)

# %%
crops[crops['Element Code'] == 5419]
# Out:
# 47         hg/ha
# 48         hg/ha
# 49         hg/ha
# 50         hg/ha
# 51         hg/ha
#            ...
# 3761102    hg/ha
# 3761103    hg/ha
# 3761104    hg/ha
# 3761105    hg/ha
# 3761106    hg/ha
# Name: Unit, Length: 761663, dtype: object

# %%
crops.rename(columns = {'Area':'Country','Value':'Yield'},inplace = True)

# %%
crops = crops[crops['Element Code'] == 5419].groupby(['Country','Year'])['Yield'].sum().reset_index()

# %%
crops
# Out:
#            Country  Year      Yield
# 0      Afghanistan  1961  1921425.0
# 1      Afghanistan  1962  1993718.0
# 2      Afghanistan  1963  1987768.0
# 3      Afghanistan  1964  2010123.0
# 4      Afghanistan  1965  2154195.0
# ...            ...   ...        ...
# 13542     Zimbabwe  2017  5051974.0
# 13543     Zimbabwe  2018  5164789.0
# 13544     Zimbabwe  2019  5102272.0
# 13545     Zimbabwe  2020  5105973.0
# 13546     Zimbabwe  2021  5086704.0
#
# [13547 rows x 3 columns]

# %%
replacements = {
    'Türkiye': 'Turkey',
    'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom',
    'Netherlands (Kingdom of the)':'Netherlands'
}

pest['Area'] = pest['Area'].replace(replacements)

# %%
pest[pest['Area'] == 'Turkey']
# Out:
#        Area Code Area Code (M49)    Area  Item Code                  Item  \
# 90032        223            '792  Turkey       1357    Pesticides (total)
# 90033        223            '792  Turkey       1357    Pesticides (total)
# 90034        223            '792  Turkey       1357    Pesticides (total)
# 90035        223            '792  Turkey       1357    Pesticides (total)
# 90036        223            '792  Turkey       1357    Pesticides (total)
# ...          ...             ...     ...        ...                   ...
# 90598        223            '792  Turkey       1355  Other Pesticides nes
# 90599        223            '792  Turkey       1355  Other Pesticides nes
# 90600        223            '792  Turkey       1355  Other Pesticides nes
# 90601        223            '792  Turkey       1355  Other Pesticides nes
# 90602        223            '792  Turkey       1355  Other Pesticides nes
#
#        Element Code           Element  Year Code  Year Unit    Value Flag
# ...

# %%
unique_values_yield = yield_df.loc[~yield_df['Country'].isin(pest['Area']), 'Country'].unique()
unique_values_yield
# Out:
# array(['Afghanistan', 'American Samoa', 'Dominica', 'Guadeloupe',
#        'Guyana', 'Martinique', 'Occupied Palestinian Territory',
#        'Puerto Rico', 'Réunion', 'Singapore', 'South Sudan',
#        'The former Yugoslav Republic of Macedonia',
#        'United Arab Emirates', 'Uzbekistan'], dtype=object)

# %%
pest.head()
# Out:
#    Area Code Area Code (M49)     Area  Item Code                Item  \
# 0          3            '008  Albania       1357  Pesticides (total)
# 1          3            '008  Albania       1357  Pesticides (total)
# 2          3            '008  Albania       1357  Pesticides (total)
# 3          3            '008  Albania       1357  Pesticides (total)
# 4          3            '008  Albania       1357  Pesticides (total)
#
#    Element Code           Element  Year Code  Year Unit  Value Flag
# 0          5157  Agricultural Use       1990  1990    t  121.0    A
# 1          5157  Agricultural Use       1991  1991    t  121.0    A
# 2          5157  Agricultural Use       1992  1992    t  121.0    A
# 3          5157  Agricultural Use       1993  1993    t  121.0    A
# 4          5157  Agricultural Use       1994  1994    t  201.0    A
